# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from itertools import product
from xgboost import XGBClassifier
from sklearn.metrics import average_precision_score, roc_auc_score, f1_score, recall_score, accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from tqdm.auto import tqdm
import math
import mlflow
import os

os.environ["DATABRICKS_HOST"] = "https://dbc-e0c2984f-335b.cloud.databricks.com/"
os.environ["DATABRICKS_TOKEN"] = ""
mlflow.set_tracking_uri("databricks")
mlflow.set_experiment("/Desarrollo_de_Soluciones/XGBoost_TFIDF")
# Out:
# 2025/09/06 01:57:52 INFO mlflow.tracking.fluent: Experiment with name '/Desarrollo_de_Soluciones/XGBoost_TFIDF' does not exist. Creating a new experiment.
# <Experiment: artifact_location='dbfs:/databricks/mlflow-tracking/2612200044042790', creation_time=1757116672940, experiment_id='2612200044042790', last_update_time=1757116672940, lifecycle_stage='active', name='/Desarrollo_de_Soluciones/XGBoost_TFIDF', tags={'mlflow.experiment.sourceName': '/Desarrollo_de_Soluciones/XGBoost_TFIDF',
#  'mlflow.experimentType': 'MLFLOW_EXPERIMENT',
#  'mlflow.ownerEmail': 'j.rico566@uniandes.edu.co',
#  'mlflow.ownerId': '75126365786967'}>

# %%
# cargar los datos

data_training = pd.read_csv("../data/cleaned_train_dataset.csv")
data_test = pd.read_csv("../data/cleaned_test_dataset.csv")
data_validation = pd.read_csv("../data/cleaned_val_dataset.csv")

# %%
data_training.tail()
# Out:
#                                                   text  label
# 811  higher blood levels of pyridoxal 5'-phosphate ...      0
# 812  pectin-based films are wrapping that is made f...      0
# 813  ste20 (sterile 20)/sps-1 related proline/alani...      1
# 814  development of a human model of hemorrhage has...      1
# 815  the local, systemic, and referred causes of fi...      1

# %%
# Revisar ejemplosd e los textos

for x in data_training["text"][:4]:
    print(x, "\n")
# Out:
# inborn errors of metabolism (iem) are hereditary diseases that affect how the body processes nutrients. they vary both in how they appear in a patient and in they underlying genetic causes. to date, more than 1000 different iem have been identified. though each individual disease is rare, taken altogether the rate has been shown to be upwards of 1 in 800. the way the diseases appear in patients can vary. this makes it difficult it diagnose them. iem are present in all ethnic groups and across every age. some iem can be treated, with promising outcomes. however, doctors suspecting these diseases from patient exams is not enough alone to reduce health problems and death. in the last decade, expanded newborn screening has become a mandatory public health strategy in most developed and developing countries. this is due to the advent of a chemical detection technology called tandem mass spectrometry. this technology allows more than 30 different metabolic disorders to be detected at low cost in one single blood spot specimen. the cost is about 10 dollars per baby, and the tests are highly accurate. studies of cost-effectiveness have confirmed that the savings from expanded newborn screening programs are much greater than the costs of running them. the side effects of false positives (when the test is positive but the patient does not have the disease) are not significant in light of the economic and health benefits produced by expanded newborn screening. further, these side effects could be lessened with more education, better communication, and improved technology. local screening agencies should be given the freedom to create their own screening programs so they can keep up with international advancements. improvements in knowledge of genes and how they affect the body are closely linked with expanded newborn screening. this knowledge is growing because of advancements in nanotechnology (working with things at the microscopic level) and molecular genomics (the study of how changes dna drive here
# central nervous system adverse effects are commonly reported with pregabalin (pgb). on the other hand, movement disorders (mds) associated with this drug were rarely described. however, their occurrence could significantly affect the quality of life of pgb users. this literature review aims to evaluate the clinical epidemiological profile, pathological mechanisms, and management of pgb-associated mds. relevant reports in six databases were identified and assessed by two reviewers without language restriction. a total of 46 reports containing 305 cases from 17 countries were assessed. the mds encountered were as follows: 184 individuals with ataxia, 61 with tremors, 39 with myoclonus, 8 with parkinsonism, 1 with restless legs syndrome, 1 with dystonia, 1 with dyskinesia, and 1 with akathisia. the mean age was 62 years (range: 23-94). the male sex was slightly predominant with 54.34%. the mean pgb dose when the md occurred was 238 mg, and neuropathic pain was the most common indication of pgb. the time from pgb start to md was < 1 month at 75%. the time from pgb withdrawal to recovery was < 1 week at 77%. all the individuals where the follow-up was reported had a full recovery. the most common management was pgb withdrawal. in the literature, the majority of the cases did not report information about timeline events, neurological examination details, or electrodiagnostic studies. the best management for all mds is probably pgb withdrawal. if the patient is on dialysis program, perhaps an increased number of sessions will decrease recovery time. furthermore, the addition of a benzodiazepine could accelerate recovery.

# %%
data_training["label"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90,
    ylabel=""   # quita el label "label"
)
plt.title("Distribución de etiquetas")
plt.show()

# %%
# Crear vectores a partir de los datos

tfidf_vectorizer = TfidfVectorizer()
X_train = tfidf_vectorizer.fit_transform(data_training["text"].astype(str).tolist())
X_test = tfidf_vectorizer.transform(data_test["text"].astype(str).tolist())
X_validation = tfidf_vectorizer.transform(data_validation["text"].astype(str).tolist())


y_train = data_training["label"].astype(int).values
y_test  = data_test["label"].astype(int).values  
y_val   = data_validation["label"].astype(int).values

# %%
print(f"tamanio de la data vectorizada: {X_train.shape[0]} muestras de {X_train.shape[1]} dimensiones")
# Out:
# tamanio de la data vectorizada: 816 muestras de 10437 dimensiones

# %%
# XGBoost: calcula scale_pos_weight para el desbalance


pos = (y_train == 1).sum()
neg = (y_train == 0).sum()
spw = neg / pos

# %%
tfidf_grid = {
    "ngram_range": [(1,1), (1,2)],
    "min_df": [0.01, 0.05],
    "max_features": [5000, 10000],  # tamaño del vocabulario
}

xgb_grid = {
    "learning_rate": [0.1, 0.05],
    "n_estimators": [400, 600, 800],
    "max_depth": [4, 6, 8],
}

# %%
def grid_items(grid):
    keys = list(grid.keys())
    for values in product(*[grid[k] for k in keys]):
        yield dict(zip(keys, values))

# %%
# total de combinaciones
total = math.prod(len(v) for v in tfidf_grid.values()) * math.prod(len(v) for v in xgb_grid.values())
pbar = tqdm(total=total, desc="Runs", leave=True)

for tfidf_params in grid_items(tfidf_grid):
    vec = TfidfVectorizer(**tfidf_params)
    X_train = vec.fit_transform(data_training["text"].astype(str))
    X_val   = vec.transform(data_validation["text"].astype(str))

    model = XGBClassifier(
        objective="binary:logistic",
        tree_method="hist",
        eval_metric=["aucpr","auc"],
        scale_pos_weight=spw,
        n_jobs=-1,
        **xgb_grid
    )

    for xgb_params in grid_items(xgb_grid):
        run_name = f"tfidf_{tfidf_params['ngram_range']}_xgb_{xgb_params['max_depth']}d_{xgb_params['n_estimators']}t_{xgb_params['learning_rate']}lr"
        pbar.set_description(run_name)

        with mlflow.start_run(run_name=run_name):
            model.set_params(**xgb_params)

            mlflow.log_param("featurizer", "tfidf")
            for k, v in tfidf_params.items(): mlflow.log_param(f"tfidf_{k}", v)
            mlflow.log_param("vocab_size", int(X_train.shape[1]))
            mlflow.log_param("n_train", int(X_train.shape[0]))
            mlflow.log_param("n_val", int(X_val.shape[0]))

            for k, v in xgb_params.items(): mlflow.log_param(f"xgb_{k}", v)
            mlflow.log_param("xgb_scale_pos_weight", float(spw))

            model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], verbose=False)

            val_scores = model.predict_proba(X_val)[:, 1]
            val_pred = (val_scores >= 0.5).astype(int)

            metrics = {
                "pr_auc": float(average_precision_score(y_val, val_scores)),
                "roc_auc": float(roc_auc_score(y_val, val_scores)),
                "f1": float(f1_score(y_val, val_pred)),
                "recall": float(recall_score(y_val, val_pred)),
                "accuracy": float(accuracy_score(y_val, val_pred)),
            }
            
            mlflow.log_metrics(metrics)
            
        pbar.update(1)

pbar.close()
# Out:
# Runs:   0%|          | 0/144 [00:00<?, ?it/s]
# 🏃 View run tfidf_(1, 1)_xgb_4d_400t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/fc7d014bc8d044c086c7db77c395c939
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_400t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/9bb4bce6802541a2a18085eace563175
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_400t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/4c5a160b0d2e4dce9dcdb2b6ccb29739
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_600t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/32a6d15c629f496ebffdf9e1832c17b4
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_600t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/991408b83b2740b4b6a5c6bdf04b4b29
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_600t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/c3ca5352a00841918ed0192ec05fd975
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_800t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/e75ae835533f4760a2658905bd3ffcf0
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_800t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/8d6452b1f12a40eab270a354bdfe1c86
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_800t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/b5a4f302bf584b3f87170dcb2571b063
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_400t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/5192067c4bf54528be50f9c6b85ce602
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_400t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/f22ee08460834bb0afa1765c209242df
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_400t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/f2bd4ed4a87c40e9bea7277feedc563e
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_600t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/1d9d2ef1664348f99f88e54c58c23c53
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_600t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/c8b6d0c789e94392b52afbeab28678bd
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_600t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/c48e96336baa427b9d701421c0f8b75b
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_800t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/db5d9d0052204ec8bb75d89cf329eafa
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_800t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/63772addbfdd47bd812a3d953f486f44
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_800t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/1327b720ffb84f378474e1ff8eb014e2
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_400t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/3acbc9fb409c43619b2c535843a0c8b9
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_400t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/ed12d3e0bda642089d4fcec7a67fae41
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_400t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/2da07890bc624bb3a8760eb1dfa43a08
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_600t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/cfd03d21b96a48a389aa58bb8f5eb736
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_600t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/9c0dc86c5867415f8d5d12e7926d8951
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_600t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/1c78c6397a6b414d85dbf122968c38e5
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_800t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/cf17c75f1ef34cb391ebb8021114c676
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_800t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/8f4023a13aa74b3f80cbf2b0238bfffc
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_800t_0.1lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/68313bf8b5f64da8a767b53fe076267b
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_400t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/ce8643d931dc48a987fcc4d3945be8d6
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_400t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/d988c221659648b59f5c3d643f8e7347
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_400t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/2519372127b948fdb4ebf21f660606e0
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_600t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/8395e92dfe4c43fdb777a827269e1ad5
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_600t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/af3f3f55d05a46a1a429772a6ddab9af
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_8d_600t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/0e29f14fead24040885b0a498237f603
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_4d_800t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs/be3c0c2273c84462b170fdf10448d8a7
# 🧪 View experiment at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790
# 🏃 View run tfidf_(1, 1)_xgb_6d_800t_0.05lr at: https://dbc-e0c2984f-335b.cloud.databricks.com/ml/experiments/2612200044042790/runs